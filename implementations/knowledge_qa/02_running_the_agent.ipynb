# %% [markdown]
# # 02: Running the Agent
#
# In Notebook 01 we explored the dataset and tools. This notebook shows how to run the
# `KnowledgeGroundedAgent` in practice.
#
# ## What You'll Learn
#
# 1. The agent's PlanReAct architecture and the `AgentResponse` data structure
# 2. Running a question with live progress display
# 3. Inspecting the response: plan, tool calls, sources, and reasoning
# 4. Multi-turn conversations using session state
# 5. Observability with Langfuse tracing
#
# ## Prerequisites
#
# Complete Notebook 01. You'll need `GOOGLE_API_KEY` in your `.env` file.
# For tracing (Section 4): `LANGFUSE_PUBLIC_KEY` and `LANGFUSE_SECRET_KEY` are also required.

# %%
import os
import uuid
from pathlib import Path

from aieng.agent_evals.knowledge_qa import KnowledgeGroundedAgent
from aieng.agent_evals.knowledge_qa.notebook import display_response, run_with_display
from aieng.agent_evals.langfuse import init_tracing
from dotenv import load_dotenv
from rich.console import Console
from rich.panel import Panel
from rich.table import Table


if Path("").absolute().name == "eval-agents":
    print(f"Working directory: {Path('').absolute()}")
else:
    os.chdir(Path("").absolute().parent.parent)
    print(f"Working directory set to: {Path('').absolute()}")

load_dotenv(verbose=True)
console = Console(width=100)
# Out:
# Working directory set to: /home/coder/eval-agents

# %% [markdown]
# ## 1. Agent Architecture
#
# The `KnowledgeGroundedAgent` is built on Google ADK and combines two patterns:
#
# **PlanReAct** — Before executing, the agent produces an explicit research plan with numbered
# steps. Each step has a type (`SEARCH`, `FETCH`, `ANALYZE`) and a status that transitions from
# `pending` → `in_progress` → `completed` (or `failed`/`skipped`). The plan can be revised
# mid-run if the agent encounters unexpected results.
#
# **ReAct loop** — Within each step, the agent alternates between reasoning (Thought), acting
# (tool call), and observing (tool response).
#
# ### The `AgentResponse` Object
#
# After running, `agent.answer_async(question)` returns an `AgentResponse`:
#
# | Field | Type | Description |
# |-------|------|-------------|
# | `text` | `str` | The final answer |
# | `plan` | `ResearchPlan` | Numbered steps with statuses |
# | `tool_calls` | `list[dict]` | Every tool invocation during execution |
# | `sources` | `list[GroundingChunk]` | URLs used as evidence |
# | `reasoning_chain` | `list[str]` | The model's intermediate reasoning |
# | `total_duration_ms` | `int` | Wall-clock execution time |

# %%
agent = KnowledgeGroundedAgent(enable_planning=True)

config_table = Table(title="Agent Configuration", show_header=False)
config_table.add_column("Setting", style="cyan")
config_table.add_column("Value", style="white")
config_table.add_row("Model", agent.model)
config_table.add_row("Planning", "PlanReAct (enabled)")
config_table.add_row("Session Service", "InMemorySessionService")
config_table.add_row("Tools", "google_search, web_fetch, fetch_file, grep_file, read_file")

console.print(config_table)
# Out:
# 2026-02-26 19:25:05,661 WARNING google_genai._api_client: Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
#                               Agent Configuration
# ┌─────────────────┬────────────────────────────────────────────────────────────┐
# │ Model           │ gemini-2.5-flash                                           │
# │ Planning        │ PlanReAct (enabled)                                        │
# │ Session Service │ InMemorySessionService                                     │
# │ Tools           │ google_search, web_fetch, fetch_file, grep_file, read_file │
# └─────────────────┴────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## 2. Running a Question
#
# `run_with_display` executes the agent in a Jupyter notebook with a live progress display showing:
#
# - The research plan with step statuses (updating in real time)
# - Tool calls as they fire
#
# We'll use a question that requires web search — the agent must find and verify a specific fact,
# not recall it from training data.

# %%
question = "When was the highest single-day snowfall recorded in Toronto, and how much snow fell?"

response = await run_with_display(agent, question)
# Out:
# <div style="max-width: 800px;">
# <div style="padding: 10px; background: #cfe2ff; border-radius: 8px; margin-bottom: 8px;"><b>Question:</b> When was the highest single-day snowfall recorded in Toronto, and how much snow fell?</div>
# <div style="font-family: monospace; padding: 10px; background: #f8f9fa; border-radius: 8px;">
# <div style="font-weight: bold; margin-bottom: 8px;">📋 Research Plan</div>
# <div style="color: #ffc107; margin: 4px 0;">→ 1. Search Google for "highest single-day snowfall Toronto".</div>
# <div style="color: #adb5bd; margin: 4px 0;">○ 2. From the search results, identify a reliable source (e.g., a reputable weather agency, news archive, or meteorological record site).</div>
# <div style="color: #adb5bd; margin: 4px 0;">○ 3. Use `web_fetch` to extract the date and amount of snowfall from the identified source.</div>
# <div style="color: #adb5bd; margin: 4px 0;">○ 4. If multiple sources provide conflicting information, try to find a consensus or prioritize official sources.</div>
# <div style="color: #adb5bd; margin: 4px 0;">○ 5. Provide the final answer with the date, amount of snow, and the source URL.</div>
# </div>
# <div style="font-family: monospace; padding: 10px; background: #e9ecef; border-radius: 8px; margin-top: 8px;">
# <div style="font-weight: bold; margin-bottom: 8px;">🔧 Tool Calls (1)</div>
# <div style="margin: 2px 0;"><span style="color: #28a745;">✓</span> 🔍 <b>google_search</b> <span style="color: #6c757d;">{'query': 'highest single-day snowfall Toronto'}</span></div>
# </div>
# </div>
# 2026-02-26 19:25:41,105 WARNING google_adk.google.adk.models.gemini_context_cache_manager: Failed to create cache: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'TotalCachedContentStorageTokensPerModelFreeTier limit exceeded for model gemini-2.5-flash: limit=0, requested=2918', 'status': 'RESOURCE_EXHAUSTED'}}
# 2026-02-26 19:25:41,107 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/eval-agents/.venv/lib/python3.12/site-packages/google/adk/models/google_llm.py:241, in Gemini.generate_content_async(self, llm_request, stream)
#     240 else:
# --> 241   response = await self.api_client.aio.models.generate_content(
#     242       model=llm_request.model,
#     243       contents=llm_request.contents,
#     244       config=llm_request.config,
#     245   )
#     246   logger.info('Response received from the model.')
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/google/genai/models.py:7030, in AsyncModels.generate_content(self, model, contents, config)
#    7023     logger.warning(
#    7024         'Tools at indices [%s] are not compatible with automatic function '
#    7025         'calling (AFC). AFC is disabled. If AFC is intended, please '
#    (...)   7028         indices_str,
#    7029     )
# -> 7030   return await self._generate_content(
#    7031       model=model, contents=contents, config=parsed_config
#    7032   )
#    7033 remaining_remote_calls_afc = _extra_utils.get_max_remote_calls_afc(
#    7034     parsed_config
#    7035 )
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/google/genai/models.py:5848, in AsyncModels._generate_content(self, model, contents, config)
#    5846 request_dict = _common.encode_unserializable_types(request_dict)
# -> 5848 response = await self._api_client.async_request(
#    5849     'post', path, request_dict, http_options
#    5850 )
#    5852 if config is not None and getattr(
#    5853     config, 'should_return_http_response', None
#    5854 ):
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1432, in BaseApiClient.async_request(self, http_method, path, request_dict, http_options)
#    1428 http_request = self._build_request(
#    1429     http_method, path, request_dict, http_options
#    1430 )
# -> 1432 result = await self._async_request(
#    1433     http_request=http_request, http_options=http_options, stream=False
#    1434 )
#    1435 response_body = result.response_stream[0] if result.response_stream else ''
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1365, in BaseApiClient._async_request(self, http_request, http_options, stream)
#    1364     return await retry(self._async_request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1365 return await self._async_retry(  # type: ignore[no-any-return]
#    1366     self._async_request_once, http_request, stream
#    1367 )
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py:111, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#     110 while True:
# --> 111     do = await self.iter(retry_state=retry_state)
#     112     if isinstance(do, DoAttempt):
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py:153, in AsyncRetrying.iter(self, retry_state)
#     152 for action in self.iter_state.actions:
# --> 153     result = await action(retry_state)
#     154 return result
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/tenacity/_utils.py:99, in wrap_to_async_func.<locals>.inner(*args, **kwargs)
#      98 async def inner(*args: typing.Any, **kwargs: typing.Any) -> typing.Any:
# ---> 99     return call(*args, **kwargs)
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/tenacity/__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/tenacity/__init__.py:187, in RetryError.reraise(self)
#     186 if self.last_attempt.failed:
# --> 187     raise self.last_attempt.result()
#     188 raise self
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py:114, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#     113 try:
# --> 114     result = await fn(*args, **kwargs)
#     115 except BaseException:  # noqa: B902
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1310, in BaseApiClient._async_request_once(self, http_request, stream)
#    1302 response = await self._aiohttp_session.request(
#    1303     method=http_request.method,
#    1304     url=http_request.url,
#    (...)   1308     **self._async_client_session_request_args,
#    1309 )
# -> 1310 await errors.APIError.raise_for_async_response(response)
#    1311 return HttpResponse(response.headers, [await response.text()])
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/google/genai/errors.py:203, in APIError.raise_for_async_response(cls, response)
#     201     raise ValueError(f'Unsupported response type: {type(response)}')
# --> 203 await cls.raise_error_async(status_code, response_json, response)
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/google/genai/errors.py:225, in APIError.raise_error_async(cls, status_code, response_json, response)
#     224 if 400 <= status_code < 500:
# --> 225   raise ClientError(status_code, response_json, response)
#     226 elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 18.850149011s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '18s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# _ResourceExhaustedError                   Traceback (most recent call last)
# File ~/eval-agents/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py:114, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#     113 try:
# --> 114     result = await fn(*args, **kwargs)
#     115 except BaseException:  # noqa: B902
#
# File ~/eval-agents/aieng-eval-agents/aieng/agent_evals/knowledge_qa/agent.py:597, in KnowledgeGroundedAgent._run_agent_once.<locals>._run_with_retry()
#     585 @retry(
#     586     retry=retry_if_exception(is_retryable_api_error),
#     587     wait=wait_exponential_jitter(
#    (...)    595 )
#     596 async def _run_with_retry() -> dict[str, Any]:
# --> 597     return await self._run_agent_once_inner(question, adk_session_id)
#
# File ~/eval-agents/aieng-eval-agents/aieng/agent_evals/knowledge_qa/agent.py:561, in KnowledgeGroundedAgent._run_agent_once_inner(self, question, adk_session_id)
#     560 event_count = 0
# --> 561 async for event in self._runner.run_async(
#     562     user_id="user",
#     563     session_id=adk_session_id,
#     564     new_message=content,
#     565 ):
#     566     event_count += 1
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/google/adk/runners.py:562, in Runner.run_async(self, user_id, session_id, invocation_id, new_message, state_delta, run_config)
#     561 async with Aclosing(_run_with_trace(new_message, invocation_id)) as agen:
# --> 562   async for event in agen:
#     563     yield event
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/google/adk/runners.py:550, in Runner.run_async.<locals>._run_with_trace(new_message, invocation_id)
#     542 async with Aclosing(
#     543     self._exec_with_plugin(
#     544         invocation_context=invocation_context,
#    (...)    548     )
#     549 ) as agen:
# --> 550   async for event in agen:
#     551     yield event
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/google/adk/runners.py:779, in Runner._exec_with_plugin(self, invocation_context, session, execute_fn, is_live_call)
#     778 async with Aclosing(execute_fn(invocation_context)) as agen:
# --> 779   async for event in agen:
#     780     _apply_run_config_custom_metadata(
#     781         event, invocation_context.run_config
#     782     )
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/google/adk/runners.py:539, in Runner.run_async.<locals>._run_with_trace.<locals>.execute(ctx)
#     538 async with Aclosing(ctx.agent.run_async(ctx)) as agen:
# --> 539   async for event in agen:
#     540     yield event
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/google/adk/agents/base_agent.py:294, in BaseAgent.run_async(self, parent_context)
#     293 async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 294   async for event in agen:
#     295     yield event
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/google/adk/agents/llm_agent.py:468, in LlmAgent._run_async_impl(self, ctx)
#     467 async with Aclosing(self._llm_flow.run_async(ctx)) as agen:
# --> 468   async for event in agen:
#     469     self.__maybe_save_output_to_state(event)
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:382, in BaseLlmFlow.run_async(self, invocation_context)
#     381 async with Aclosing(self._run_one_step_async(invocation_context)) as agen:
# --> 382   async for event in agen:
#     383     last_event = event
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:459, in BaseLlmFlow._run_one_step_async(self, invocation_context)
#     454 async with Aclosing(
#     455     self._call_llm_async(
#     456         invocation_context, llm_request, model_response_event
#     457     )
#     458 ) as agen:
# --> 459   async for llm_response in agen:
#     460     # Postprocess after calling the LLM.
#     461     async with Aclosing(
#     462         self._postprocess_async(
#     463             invocation_context,
#    (...)    467         )
#     468     ) as agen:
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:835, in BaseLlmFlow._call_llm_async(self, invocation_context, llm_request, model_response_event)
#     834 async with Aclosing(_call_llm_with_tracing()) as agen:
# --> 835   async for event in agen:
#     836     yield event
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:819, in BaseLlmFlow._call_llm_async.<locals>._call_llm_with_tracing()
#     811 async with Aclosing(
#     812     self._run_and_handle_error(
#     813         responses_generator,
#    (...)    817     )
#     818 ) as agen:
# --> 819   async for llm_response in agen:
#     820     trace_call_llm(
#     821         invocation_context,
#     822         model_response_event.id,
#     823         llm_request,
#     824         llm_response,
#     825     )
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:1067, in BaseLlmFlow._run_and_handle_error(self, response_generator, invocation_context, llm_request, model_response_event)
#    1066 else:
# -> 1067   raise model_error
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:1053, in BaseLlmFlow._run_and_handle_error(self, response_generator, invocation_context, llm_request, model_response_event)
#    1052 async with Aclosing(response_generator) as agen:
# -> 1053   async for response in agen:
#    1054     yield response
#
# File ~/eval-agents/.venv/lib/python3.12/site-packages/google/adk/models/google_llm.py:260, in Gemini.generate_content_async(self, llm_request, stream)
#     256 if ce.code == 429:
#     257   # We expect running into a Resource Exhausted error to be a common
#     258   # client error that developers would run into. We enhance the messaging
#     259   # with possible fixes to this issue.
# --> 260   raise _ResourceExhaustedError(ce) from ce
#     262 raise ce
#
# _ResourceExhaustedError:
# On how to mitigate this issue, please refer to:
#
# https://google.github.io/adk-docs/agents/models/#error-code-429-resource_exhausted
#
#
# 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 18.850149011s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '18s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 3
#       1 question = "When was the highest single-day snowfall recorded in Toronto, and how much snow fell?"
# ----> 3 response = await run_with_display(agent, question)
#
# File ~/eval-agents/aieng-eval-agents/aieng/agent_evals/knowledge_qa/notebook.py:310, in run_with_display(agent, question, refresh_rate)
#     307     await asyncio.sleep(refresh_rate)
#     309 # Get the result
# --> 310 response = await task
#     312 # Final display with completion status
#     313 clear_output(wait=True)
#
# File ~/eval-agents/aieng-eval-agents/aieng/agent_evals/knowledge_qa/agent.py:666, in KnowledgeGroundedAgent.answer_async(self, question, session_id)
#     663 current_session_id = adk_session_id
#     665 for attempt in range(MAX_EMPTY_RESPONSE_RETRIES + 1):
# --> 666     results = await self._run_agent_once(question, current_session_id)
#     668     # Check if we got a non-empty response
#     669     if results.get("final_response", "").strip():
#
# File ~/eval-agents/aieng-eval-agents/aieng/agent_evals/knowledge_qa/agent.py:605, in KnowledgeGroundedAgent._run_agent_once(self, question, adk_session_id)
#     603     original_error = e.last_attempt.exception()
#     604     logger.error(f"API retry failed after {API_RETRY_MAX_ATTEMPTS} attempts: {original_error}")
# --> 605     raise RuntimeError(
#     606         f"API request failed after {API_RETRY_MAX_ATTEMPTS} retry attempts. Last error: {original_error}"
#     607     ) from original_error
#     608 except ClientError as e:
#     609     # Handle context overflow by resetting session
#     610     if is_context_overflow_error(e):
#
# RuntimeError: API request failed after 5 retry attempts. Last error:
# On how to mitigate this issue, please refer to:
#
# https://google.github.io/adk-docs/agents/models/#error-code-429-resource_exhausted
#
#
# 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 18.850149011s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '18s'}]}}

# %%
display_response(
    console,
    response.text,
    subtitle=(
        f"Duration: {response.total_duration_ms / 1000:.1f}s  |  "
        f"Tool calls: {len(response.tool_calls)}  |  "
        f"Sources: {len(response.sources)}"
    ),
)
# Out:
# ╭───────────────────────────────────────────── Answer ─────────────────────────────────────────────╮
# │ The highest single-day snowfall recorded in Toronto was 61 cm, which fell in downtown Toronto on │
# │ January 25, 2026.                                                                                │
# ╰──────────────────────── Duration: 31.0s  |  Tool calls: 3  |  Sources: 7 ────────────────────────╯
# ╭─────────────────────────────────────────── Reasoning ────────────────────────────────────────────╮
# │ The CityNews article, published on January 26, 2026, states, "Environment Canada’s updated       │
# │ snowfall analysis shows 61 cm fell in downtown Toronto, one of the highest totals ever observed  │
# │ in the core." It also refers to "Sunday’s now-record-setting storm," confirming the date as      │
# │ January 25, 2026. The CTV News article corroborates the date and amount, stating "The highest    │
# │ single-day snowfall in Toronto was... Date: January 25, 2026 (Sunday) Amount of snow: Nearly 60  │
# │ centimeters."                                                                                    │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ### 2.1 Inspecting the Response
#
# The `AgentResponse` object contains the full execution trace.

# %%
plan = response.plan

plan_table = Table(title="Research Plan")
plan_table.add_column("#", style="cyan", width=3)
plan_table.add_column("Step", style="white")
plan_table.add_column("Type", style="dim", width=12)
plan_table.add_column("Status", style="green")

for step in plan.steps:
    icon = {"completed": "✓", "failed": "✗", "skipped": "○"}.get(step.status.value, "·")
    desc = step.description[:70] + "..." if len(step.description) > 70 else step.description
    plan_table.add_row(str(step.step_id), desc, step.step_type, f"{icon} {step.status.value}")

console.print(plan_table)
# Out:
#                                            Research Plan
# ┏━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┓
# ┃ #   ┃ Step                                                          ┃ Type         ┃ Status      ┃
# ┡━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━┩
# │ 1   │ Search Google for "highest single-day snowfall Toronto" to    │ research     │ ✓ completed │
# │     │ find reliab...                                                │              │             │
# │ 2   │ From the search results, identify promising URLs that are     │ research     │ ✓ completed │
# │     │ likely to co...                                               │              │             │
# │ 3   │ Use `web_fetch` to extract the date and snowfall amount from  │ research     │ ✓ completed │
# │     │ the most ...                                                  │              │             │
# │ 4   │ Verify the information and provide the final answer with the  │ research     │ ○ skipped   │
# │     │ source.                                                       │              │             │
# └─────┴───────────────────────────────────────────────────────────────┴──────────────┴─────────────┘

# %%
if response.tool_calls:
    tools_table = Table(title="Tool Calls")
    tools_table.add_column("#", style="dim", width=3)
    tools_table.add_column("Tool", style="cyan", width=16)
    tools_table.add_column("Arguments (truncated)", style="white")

    for i, tc in enumerate(response.tool_calls[:15], 1):
        name = tc.get("name", "unknown")
        args = str(tc.get("args", {}))
        args = args[:70] + "..." if len(args) > 70 else args
        tools_table.add_row(str(i), name, args)

    if len(response.tool_calls) > 15:
        tools_table.add_row("...", f"({len(response.tool_calls) - 15} more)", "")

    console.print(tools_table)
else:
    console.print("[dim]No tool calls recorded[/dim]")
# Out:
#                                              Tool Calls
# ┏━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ #   ┃ Tool             ┃ Arguments (truncated)                                                   ┃
# ┡━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 1   │ google_search    │ {'query': 'highest single-day snowfall Toronto'}                        │
# │ 2   │ web_fetch        │ {'url':                                                                 │
# │     │                  │ 'https://www.ctvnews.ca/toronto/article/what-a-winter-wallop-s...       │
# │ 3   │ web_fetch        │ {'query': 'highest single-day snowfall in Toronto, date, and amount     │
# │     │                  │ of...                                                                   │
# └─────┴──────────────────┴─────────────────────────────────────────────────────────────────────────┘

# %%
if response.sources:
    seen: set[str] = set()
    sources_table = Table(title="Sources")
    sources_table.add_column("#", style="dim", width=3)
    sources_table.add_column("URL", style="blue")

    for src in response.sources:
        if src.uri and src.uri not in seen:
            seen.add(src.uri)
            url = src.uri[:85] + "..." if len(src.uri) > 85 else src.uri
            sources_table.add_row(str(len(seen)), url)
        if len(seen) >= 10:
            break

    console.print(sources_table)
else:
    console.print("[dim]No sources recorded[/dim]")
# Out:
#                                              Sources
# ┏━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ #   ┃ URL                                                                                      ┃
# ┡━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 1   │ https://toronto.citynews.ca/2026/01/26/toronto-pearson-snowfall-record-sunday-january... │
# │ 2   │ https://www.torontotoday.ca/local/environment-climate/toronto-breaks-snowfall-records... │
# │ 3   │ https://www.currentresults.com/Yearly-Weather/Canada/ON/Toronto/extreme-annual-toront... │
# │ 4   │ https://www.ctvnews.ca/toronto/article/what-a-winter-wallop-storm-sets-new-single-day... │
# │ 5   │ https://torontolife.com/city/yesterdays-snowfall-was-the-biggest-single-day-snowstorm... │
# │ 6   │ https://www.ctvnews.ca/edmonton/article/wild-weather-record-snowfall-and-deadly-flood... │
# │ 7   │ https://www.theweathernetwork.com/en/news/weather/severe/photos-major-winter-storm-hi... │
# └─────┴──────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## 3. Multi-Turn Conversations
#
# The agent uses an `InMemorySessionService` to maintain conversation context across turns.
# Pass the same `session_id` to link questions together — the agent will use prior context
# when answering follow-up questions.

# %%
session_id = str(uuid.uuid4())
console.print(f"Session ID: [dim]{session_id}[/dim]\n")

# First turn: establish a subject
response1 = await agent.answer_async(
    "What is the capital of France?",
    session_id=session_id,
)
display_response(console, response1.text, title="Turn 1")

# Second turn: follow-up that references the prior context
response2 = await agent.answer_async(
    "What is the official language spoken there?",
    session_id=session_id,
)
display_response(console, response2.text, title="Turn 2 (follow-up)")
# Out:
# Session ID: ef9118d3-aebb-4920-ae1d-b57d6ff88425
# 2026-02-26 18:48:26,400 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: What is the capital of France?...
# 2026-02-26 18:48:26,412 WARNING google_genai._api_client: Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# 2026-02-26 18:48:26,653 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-02-26 18:48:27,418 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-02-26 18:48:27,422 INFO aieng.agent_evals.knowledge_qa.agent: Extracted plan with 4 steps
# 2026-02-26 18:48:27,423 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'capital of France'})
# 2026-02-26 18:48:27,425 WARNING google_genai._api_client: Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# 2026-02-26 18:48:27,540 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-02-26 18:48:30,670 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-02-26 18:48:30,676 WARNING google_genai._api_client: Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# 2026-02-26 18:48:30,987 WARNING google_adk.google.adk.models.gemini_context_cache_manager: Failed to create cache: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'TotalCachedContentStorageTokensPerModelFreeTier limit exceeded for model gemini-2.5-flash: limit=0, requested=2907', 'status': 'RESOURCE_EXHAUSTED'}}
# 2026-02-26 18:48:30,990 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-02-26 18:48:31,864 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-02-26 18:48:31,867 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'url': 'https://en.wikipedia.org/wiki/Paris', 'query': 'What is the capital of France?'})
# 2026-02-26 18:48:32,321 INFO aieng.agent_evals.tools.web: Fetched 200035 chars from https://en.wikipedia.org/wiki/Paris, extracting info...
# 2026-02-26 18:48:33,829 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-02-26 18:48:33,834 WARNING google_genai._api_client: Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# 2026-02-26 18:48:34,183 WARNING google_adk.google.adk.models.gemini_context_cache_manager: Failed to create cache: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'TotalCachedContentStorageTokensPerModelFreeTier limit exceeded for model gemini-2.5-flash: limit=0, requested=3224', 'status': 'RESOURCE_EXHAUSTED'}}
# 2026-02-26 18:48:34,189 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-02-26 18:48:35,194 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# ╭───────────────────────────────────────────── Turn 1 ─────────────────────────────────────────────╮
# │ The capital of France is Paris.                                                                  │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────── Sources ─────────────────────────────────────────────╮
# │   https://en.wikipedia.org/wiki/Paris                                                            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────── Reasoning ────────────────────────────────────────────╮
# │ The Wikipedia page for Paris states: "Paris is the capital and largest city of France..."        │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# 2026-02-26 18:48:35,258 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: What is the official language spoken there?...
# 2026-02-26 18:48:35,267 WARNING google_genai._api_client: Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# 2026-02-26 18:48:35,611 WARNING google_adk.google.adk.models.gemini_context_cache_manager: Failed to create cache: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'TotalCachedContentStorageTokensPerModelFreeTier limit exceeded for model gemini-2.5-flash: limit=0, requested=3440', 'status': 'RESOURCE_EXHAUSTED'}}
# 2026-02-26 18:48:35,613 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-02-26 18:48:37,034 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-02-26 18:48:37,037 INFO aieng.agent_evals.knowledge_qa.agent: Extracted plan with 4 steps
# 2026-02-26 18:48:37,039 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'official language of France'})
# 2026-02-26 18:48:37,041 WARNING google_genai._api_client: Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# 2026-02-26 18:48:37,161 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-02-26 18:48:40,193 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-02-26 18:48:40,200 WARNING google_genai._api_client: Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# 2026-02-26 18:48:40,526 WARNING google_adk.google.adk.models.gemini_context_cache_manager: Failed to create cache: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'TotalCachedContentStorageTokensPerModelFreeTier limit exceeded for model gemini-2.5-flash: limit=0, requested=3521', 'status': 'RESOURCE_EXHAUSTED'}}
# 2026-02-26 18:48:40,530 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-02-26 18:48:41,457 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-02-26 18:48:41,460 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'url': 'https://en.wikipedia.org/wiki/Languages_of_France', 'query': 'What is the official language of France?'})
# 2026-02-26 18:48:41,670 INFO aieng.agent_evals.tools.web: Fetched 108747 chars from https://en.wikipedia.org/wiki/Languages_of_France, extracting info...
# 2026-02-26 18:48:42,910 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-02-26 18:48:42,916 WARNING google_genai._api_client: Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# 2026-02-26 18:48:43,259 WARNING google_adk.google.adk.models.gemini_context_cache_manager: Failed to create cache: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'TotalCachedContentStorageTokensPerModelFreeTier limit exceeded for model gemini-2.5-flash: limit=0, requested=3777', 'status': 'RESOURCE_EXHAUSTED'}}
# 2026-02-26 18:48:43,262 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-02-26 18:48:44,263 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# ╭─────────────────────────────────────── Turn 2 (follow-up) ───────────────────────────────────────╮
# │ The official language spoken in France is French.                                                │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────── Sources ─────────────────────────────────────────────╮
# │   https://en.wikipedia.org/wiki/Languages_of_France                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────── Reasoning ────────────────────────────────────────────╮
# │ The Wikipedia page "Languages of France" states: "French is the sole official language in France │
# │ according to the second article of the French Constitution."                                     │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ## 4. Observability with Langfuse
#
# Langfuse captures a full trace of every agent run using OpenTelemetry, giving you visibility into:
#
# - Every tool call and its arguments
# - Every LLM call with prompts and completions
# - Timing for each span
# - The full agent execution tree
#
# This is essential for debugging failures, measuring latency, and comparing configurations.
#
# ### Trace Structure
#
# ```
# Trace: agent run
# ├── Span: planning (PlanReAct)
# │   └── LLM Call: create_plan
# ├── Span: step-1-execution
# │   ├── Tool Call: google_search
# │   ├── Tool Call: web_fetch
# │   └── LLM Call: step_summary
# ├── Span: step-2-execution
# │   └── ...
# └── Span: synthesis
#     └── LLM Call: final_answer
# ```
#
# ### Prerequisites
#
# Set these in your `.env` file:
# - `LANGFUSE_PUBLIC_KEY`
# - `LANGFUSE_SECRET_KEY`
# - `LANGFUSE_HOST` (optional, defaults to `https://cloud.langfuse.com`)

# %%
langfuse_configured = all(
    [
        os.getenv("LANGFUSE_PUBLIC_KEY"),
        os.getenv("LANGFUSE_SECRET_KEY"),
    ]
)

if langfuse_configured:
    console.print("[green]✓[/green] Langfuse credentials found")
else:
    console.print("[yellow]⚠[/yellow] Langfuse credentials not found — tracing cells will be skipped")
    console.print("[dim]Set LANGFUSE_PUBLIC_KEY and LANGFUSE_SECRET_KEY in .env[/dim]")
# Out:
# ✓ Langfuse credentials found

# %%
tracing_enabled = init_tracing()

if tracing_enabled:
    console.print("[green]✓[/green] Langfuse tracing initialized")
else:
    console.print("[yellow]⚠[/yellow] Tracing not enabled (check credentials)")
# Out:
# 2026-02-26 18:49:03,307 WARNING opentelemetry.trace: Overriding of current TracerProvider is not allowed
# 2026-02-26 18:49:03,445 INFO aieng.agent_evals.langfuse: Langfuse tracing initialized successfully (endpoint: https://us.cloud.langfuse.com/api/public/otel)
# ✓ Langfuse tracing initialized

# %%
if tracing_enabled:
    from langfuse import Langfuse

    langfuse = Langfuse()
    traced_agent = KnowledgeGroundedAgent(enable_planning=True)
    traced_question = "What programming language was created by Guido van Rossum, and in what year?"

    console.print(Panel(traced_question, title="Traced Question", border_style="green"))

    with langfuse.start_as_current_span(name="knowledge-agent", input=traced_question):
        trace_id = langfuse.get_current_trace_id()
        traced_response = await traced_agent.answer_async(traced_question)
        langfuse.update_current_span(output=traced_response.text)

    display_response(
        console,
        traced_response.text,
        subtitle=f"Duration: {traced_response.total_duration_ms / 1000:.1f}s",
    )
else:
    console.print("[dim]Skipping (Langfuse not configured)[/dim]")
    trace_id = None
# Out:
# 2026-02-26 18:49:05,486 WARNING google_genai._api_client: Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# ╭──────────────────────────────────────── Traced Question ─────────────────────────────────────────╮
# │ What programming language was created by Guido van Rossum, and in what year?                     │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# 2026-02-26 18:49:05,696 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: What programming language was created by Guido van Rossum, and in what year?...
# 2026-02-26 18:49:05,704 WARNING google_genai._api_client: Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# /home/coder/eval-agents/.venv/lib/python3.12/site-packages/google/adk/models/google_llm.py:172: UserWarning: [EXPERIMENTAL] GeminiContextCacheManager: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   cache_manager = GeminiContextCacheManager(self.api_client)
# 2026-02-26 18:49:05,845 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-02-26 18:49:08,838 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-02-26 18:49:08,843 INFO aieng.agent_evals.knowledge_qa.agent: Extracted plan with 4 steps
# 2026-02-26 18:49:08,845 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'programming language created by Guido van Rossum'})
# 2026-02-26 18:49:08,847 WARNING google_genai._api_client: Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# 2026-02-26 18:49:08,962 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-02-26 18:49:12,509 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-02-26 18:49:12,513 WARNING google_genai._api_client: Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# 2026-02-26 18:49:12,812 WARNING google_adk.google.adk.models.gemini_context_cache_manager: Failed to create cache: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'TotalCachedContentStorageTokensPerModelFreeTier limit exceeded for model gemini-2.5-flash: limit=0, requested=2916', 'status': 'RESOURCE_EXHAUSTED'}}
# 2026-02-26 18:49:12,815 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-02-26 18:49:13,570 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-02-26 18:49:13,574 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'url': 'https://en.wikipedia.org/wiki/Python_(programming_language)', 'query': 'when was python created and by whom'})
# 2026-02-26 18:49:13,898 INFO aieng.agent_evals.tools.web: Fetched 200035 chars from https://en.wikipedia.org/wiki/Python_(programming_language), extracting info...
# 2026-02-26 18:49:16,937 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-02-26 18:49:16,941 WARNING google_genai._api_client: Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# 2026-02-26 18:49:17,323 WARNING google_adk.google.adk.models.gemini_context_cache_manager: Failed to create cache: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'TotalCachedContentStorageTokensPerModelFreeTier limit exceeded for model gemini-2.5-flash: limit=0, requested=3422', 'status': 'RESOURCE_EXHAUSTED'}}
# 2026-02-26 18:49:17,325 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-02-26 18:49:18,690 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# ╭───────────────────────────────────────────── Answer ─────────────────────────────────────────────╮
# │ The programming language created by Guido van Rossum is Python, and it was first released in     │
# │ 1991.                                                                                            │
# ╰──────────────────────────────────────── Duration: 13.0s ─────────────────────────────────────────╯
# ╭──────────────────────────────────────────── Sources ─────────────────────────────────────────────╮
# │   https://en.wikipedia.org/wiki/Python_(programming_language)                                    │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────── Reasoning ────────────────────────────────────────────╮
# │ The Wikipedia page for Python states, "Python was conceived in the late 1980s by Guido van       │
# │ Rossum, with implementation beginning in December 1989. It was first released by Van Rossum in   │
# │ 1991 as Python 0.9.0, with the first appearance noted as February 20, 1991."                     │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
if tracing_enabled:
    from IPython.display import HTML, display  # noqa: A004
    from langfuse import Langfuse
    from opentelemetry import trace as otel_trace

    provider = otel_trace.get_tracer_provider()
    if hasattr(provider, "force_flush"):
        provider.force_flush(timeout_millis=5000)
    console.print("[green]✓[/green] Traces flushed to Langfuse")

    if trace_id:
        trace_url = Langfuse().get_trace_url(trace_id=trace_id)
        display(HTML(f'<p>View trace: <a href="{trace_url}" target="_blank">{trace_url}</a></p>'))
# Out:
# ✓ Traces flushed to Langfuse
# <p>View trace: <a href="https://us.cloud.langfuse.com/project/cmlsf2j2w00aaad070feb13yz/traces/22a68df0d8faaa65287cd0ee7a16bde7" target="_blank">https://us.cloud.langfuse.com/project/cmlsf2j2w00aaad070feb13yz/traces/22a68df0d8faaa65287cd0ee7a16bde7</a></p>

# %% [markdown]
# ### 4.1 Viewing Traces in the Langfuse UI
#
# Open your Langfuse project and navigate to **Traces**. Each run appears as a
# tree of spans. Useful things to look at:
#
# - **Span timeline** — which steps take the most time?
# - **Tool call arguments** — what search queries did the agent use?
# - **LLM interactions** — what did the model reason about before calling each tool?
# - **Errors** — red spans show where failures occurred
#
# You can also filter by trace name, time range, or input content.

# %% [markdown]
# ## Summary
#
# In this notebook you learned:
#
# 1. **Creating the agent** — `KnowledgeGroundedAgent(enable_planning=True)` with PlanReAct
# 2. **Running questions** — `run_with_display` for live notebook progress; `agent.answer_async` for raw access
# 3. **The `AgentResponse`** — plan, tool calls, sources, reasoning, and timing in one object
# 4. **Multi-turn conversations** — linking turns with `session_id`
# 5. **Langfuse tracing** — `init_tracing()` and the Langfuse SDK for full observability
#
# **Next:** In Notebook 03, we'll run a systematic evaluation using the DeepSearchQA benchmark.

# %%
console.print(
    Panel(
        "[green]✓[/green] Notebook complete!\n\n"
        "[cyan]Next:[/cyan] Open [bold]03_evaluation.ipynb[/bold] to evaluate the agent at scale.",
        title="Done",
        border_style="green",
    )
)
# Out:
# ╭────────────────────────────────────────────── Done ──────────────────────────────────────────────╮
# │ ✓ Notebook complete!                                                                             │
# │                                                                                                  │
# │ Next: Open 03_evaluation.ipynb to evaluate the agent at scale.                                   │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
